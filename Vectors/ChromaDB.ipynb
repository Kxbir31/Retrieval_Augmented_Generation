# %%
from xml.dom.minidom import Document

from langchain_huggingface import ChatHuggingFace , HuggingFaceEndpoint
from langchain_core.embeddings import Embeddings
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
# from langchain.schema import Documents

# %%
from langchain_core.documents import Document

doc1 = Document(
    page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and ability to chase targets under pressure.",
    metadata={"team": "Royal Challengers Bengaluru"}
)

doc2 = Document(
    page_content="Rohit Sharma is one of the most successful captains in IPL history. He led Mumbai Indians to multiple IPL titles and is known for his elegant batting and leadership.",
    metadata={"team": "Mumbai Indians"}
)

doc3 = Document(
    page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. He is known for his finishing skills, wicketkeeping, and calm leadership.",
    metadata={"team": "Chennai Super Kings"}
)

doc4 = Document(
    page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers, accuracy, and excellent death bowling.",
    metadata={"team": "Mumbai Indians"}
)

doc5 = Document(
    page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, he is also known for his exceptional fielding abilities.",
    metadata={"team": "Chennai Super Kings"}
)

docs = [doc1, doc2, doc3, doc4, doc5]

# %%
Embeddings_Model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 6926.73it/s]

# %%
vector_stores = Chroma(
    embedding_function= Embeddings_Model,
    persist_directory= 'chroma_db',
    collection_name= 'samples'
)

# %%
vector_stores.add_documents(docs)
# Out:
# ['95c0e81c-3252-4a60-bb34-db84897bbb1b',
#  'b41ce45f-4d91-47d0-8366-94d2e9073e2c',
#  'c6fb2c00-7d77-4fd9-8108-3af2c1829442',
#  '95e76eec-89bd-483d-bee1-be82fbb56220',
#  'f248f6c1-7663-4771-abad-e88c94ede174']

# %%
vector_stores.similarity_search_with_score(
    query="who is a bowler?",
    k = 2
)
# Out:
# [(Document(id='95e76eec-89bd-483d-bee1-be82fbb56220', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers, accuracy, and excellent death bowling.'),
#   0.9957989454269409),
#  (Document(id='f248f6c1-7663-4771-abad-e88c94ede174', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, he is also known for his exceptional fielding abilities.'),
#   1.121297836303711)]
