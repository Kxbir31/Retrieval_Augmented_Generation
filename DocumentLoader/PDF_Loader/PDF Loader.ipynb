# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_community.document_loaders import PyPDFLoader

# %%
import os

from openai import OpenAI

model = ChatOpenAI(
    api_key=MOONSHOT_API_KEY,
    base_url="https://api.moonshot.ai/v1",
)

# %%
loader = PyPDFLoader('Case_study.pdf')
docs = loader.load()

# %%
print(len(docs))
# Out:
# 13

# %%
print(docs[0].page_content)
# Out:
# The Fork in the Road: How LibreOffice Was Born  |  Open Source Software — Case Study
# NGMC | Open Source Software Page
# THE FORK IN THE ROAD:
# How LibreOffice Was Born from a Crisis of Trust
#
#
#
# A Case Study in Open Source Governance, Community,
# and the Ethics of Control
#
# Course:  Open Source Software — NGMC
# Type:  Individual Case Study
# Submission Deadline:  31st March, 2026
#
# Name:  Kabir Bhardwaj
# Registration Number: 24BCE11226
#
# VITyarthi Portal Submission

# %%
prompt = PromptTemplate(
    template='summarise the document in easy language -\n{doc}',
    input_variables = ['doc']
)

# %%
parser = StrOutputParser()

# %%
chain = prompt | model | parser

# %%
result = chain.invoke({'doc': docs})
