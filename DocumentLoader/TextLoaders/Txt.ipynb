# %%
from tempfile import template

from IPython.core.debugger import prompt
from langchain_huggingface import ChatHuggingFace , HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_community.document_loaders import TextLoader
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
loader = TextLoader('Cricket.txt')

# %%
docs = loader.load()

# %%
print(docs)
# Out:
# [Document(metadata={'source': 'Cricket.txt'}, page_content="Cricket – A Popular Game\n\nCricket is one of the most popular sports in the world, especially in countries like India, Australia, England, Pakistan, and South Africa. It is played between two teams of eleven players each on a large circular or oval-shaped ground. The game is played with a bat and a ball, and the main objective is to score more runs than the opposing team. Cricket is enjoyed by people of all ages because it combines skill, strategy, teamwork, and sportsmanship.\n\nA cricket match begins with a toss to decide which team will bat or bowl first. The batting team tries to score runs by hitting the ball and running between the wickets or by hitting boundaries. The bowling and fielding team aims to dismiss the batters and prevent them from scoring. The team with the highest number of runs at the end of the match is declared the winner. Cricket is played in different formats, including Test matches, One Day Internationals (ODIs), and Twenty20 (T20), each offering a unique style of play.\n\nCricket teaches many valuable life lessons. It helps players develop discipline, patience, leadership, teamwork, and decision-making skills. It also improves physical fitness, hand-eye coordination, and mental concentration. Players learn to respect their opponents and follow the rules of the game, making cricket a true gentleman's sport.\n\nIn India, cricket is more than just a game; it is often considered a passion. Famous players like Sachin Tendulkar, Virat Kohli, and M.S. Dhoni have inspired millions of young people to take up the sport. Major tournaments such as the ICC Cricket World Cup and the Indian Premier League (IPL) attract huge audiences across the globe.\n\nIn conclusion, cricket is an exciting and entertaining game that brings people together regardless of age or background. It promotes healthy competition, unity, and sportsmanship. Its popularity continues to grow, making it one of the most loved sports in the world.\n")]

# %%
prompt = PromptTemplate(
    template= 'Write a summary of the following data -\n{poem}',
    input_variables=['poem']

)

# %%
parser = StrOutputParser()

# %%
import os

llm = HuggingFaceEndpoint(
    repo_id="deepseek-ai/DeepSeek-V4-Pro",
    task="text-generation",
    huggingfacehub_api_token="HUGGINGFACEHUB_ACCESS_TOKEN",
    temperature=0.8
)

model = ChatHuggingFace(llm = llm)

# %%
chain = prompt | model | parser

# %%
chain.invoke({'poem':docs})
