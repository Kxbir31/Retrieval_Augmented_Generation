# %%
from tempfile import template

from IPython.core.debugger import prompt
from langchain_huggingface import ChatHuggingFace , HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_community.document_loaders import DirectoryLoader , PyPDFLoader
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
loader = DirectoryLoader(
    path ='books',
    glob = "*.pdf",
    loader_cls = PyPDFLoader,
)
docs = loader.load()

# %%
print(len(docs))
# Out:
# 17

# %%
print(docs[2].page_content)
# Out:
# Title of the Project1. Student DetailsName:Register Number:Slot:Semester:Subject:2. AbstractA brief description of the project including the problem addressed, the basic approach used, and the outcome of the project.3. Introduction- Brief background of the project- Need for the project- Real-world relevance4. Objective of the Project- Objective 1- Objective 2 5. System Overview / Methodology- Overall working of the system- Block diagram explanation (optional)- Step-by-step process6. Hardware and Software UsedHardware:- Component 1- Component 2Software:- Programming language- Tools / IDE7. Results- Output obtained- Screenshots / photos (if any)- Brief result explanation8. ConclusionSummary of the work done and learning outcomes.Note:1.Maximum of 6 pages of report is sufficient
